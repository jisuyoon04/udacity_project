# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models

import time
from PIL import Image
import seaborn as sns

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])
test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])
validation_trasforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])
# TODO: Load the datasets with ImageFolder
train_image_datasets = datasets.ImageFolder(train_dir, transform=train_transforms)
test_image_datasets = datasets.ImageFolder(test_dir, transform=test_transforms)
validation_image_datasets = datasets.ImageFolder(valid_dir, transform=validation_trasforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_dataloaders = torch.utils.data.DataLoader(train_image_datasets, 
                                                batch_size= 32, shuffle= True)
test_dataloaders = torch.utils.data.DataLoader(test_image_datasets, 
                                               batch_size = 32, shuffle=True)
validation_dataloaders = torch.utils.data.DataLoader(validation_image_datasets, 
                                                     batch_size= 32, shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network
model = models.vgg11(pretrained=True)
model
# Out:
# Downloading: "https://download.pytorch.org/models/vgg11-bbd30ac9.pth" to /root/.torch/models/vgg11-bbd30ac9.pth
# 100%|██████████| 531456000/531456000 [00:05<00:00, 99125697.25it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# Freeze parameters in order to avoid backpropagation through them
for param in model.parameters():
    param.requires_grad = False

# Define new classifier    
from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
    ('fc1', nn.Linear(25088, 512)),
    ('relu1', nn.ReLU()),
    ('dropout1', nn.Dropout(p=0.2)),
    ('fc2', nn.Linear(512, 102)),
    ('output', nn.LogSoftmax(dim=1))
]))

model.classifier = classifier
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=512, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2)
#     (fc2): Linear(in_features=512, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
# Define criterion and optimizer
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# Training & Validation
model.to(device)
epochs = 5
steps = 0
print_every = 5
running_loss = 0

losses_train, losses_validation = [], []
for e in range(epochs):
    start = time.time()
    
    for inputs, labels in train_dataloaders:
        steps += 1
        # Move inputs and labels tensor to GPU / CPU
        inputs, labels = inputs.to(device), labels.to(device)
        
        # clear parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model.forward(inputs)
        # Calculate loss
        loss_train = criterion(outputs, labels)
        # Backward pass
        loss_train.backward()
        # Update the parameters
        optimizer.step()
        
        running_loss += loss_train.item()
        
        # Validation
        if steps % print_every == 0:
            loss_validation = 0
            accuracy = 0
            model.eval()
            with torch.no_grad():
                model.to(device)
                for inputs, labels in validation_dataloaders:
                    inputs, labels = inputs.to(device), labels.to(device)
                    
                    outputs = model.forward(inputs)
                    loss_batch = criterion(outputs, labels)
                    loss_validation += loss_batch.item()
                    
                    # Calculate probability
                    ps = torch.exp(outputs)
                    top_p, top_class = ps.topk(1, dim=1)
        
                    # Calculate accuracy
                    equality = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equality.type(torch.FloatTensor)).item()
            
            losses_train.append(running_loss/len(train_dataloaders))
            losses_validation.append(loss_validation/len(validation_dataloaders))
        
            print(f"Epoch {e+1}/{epochs}.. "
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Validation loss: {loss_validation/len(validation_dataloaders):.3f}.. "
                  f"Accuracy: {accuracy/len(validation_dataloaders):.3f}")
            
            running_loss = 0
            model.train()
    calc_time = time.time() - start
    print(f"Time per epoch: {calc_time} seconds")
# Out:
# Epoch 1/5.. Train loss: 5.160.. Validation loss: 5.026.. Accuracy: 0.090
# Epoch 1/5.. Train loss: 4.662.. Validation loss: 4.243.. Accuracy: 0.145
# Epoch 1/5.. Train loss: 4.255.. Validation loss: 3.931.. Accuracy: 0.238
# Epoch 1/5.. Train loss: 3.928.. Validation loss: 3.592.. Accuracy: 0.253
# Epoch 1/5.. Train loss: 3.574.. Validation loss: 3.140.. Accuracy: 0.311
# Epoch 1/5.. Train loss: 3.570.. Validation loss: 2.838.. Accuracy: 0.367
# Epoch 1/5.. Train loss: 3.367.. Validation loss: 2.651.. Accuracy: 0.417
# Epoch 1/5.. Train loss: 3.271.. Validation loss: 2.529.. Accuracy: 0.442
# Epoch 1/5.. Train loss: 2.986.. Validation loss: 2.346.. Accuracy: 0.464
# Epoch 1/5.. Train loss: 2.662.. Validation loss: 2.173.. Accuracy: 0.499
# Epoch 1/5.. Train loss: 2.489.. Validation loss: 1.995.. Accuracy: 0.546
# Epoch 1/5.. Train loss: 2.453.. Validation loss: 1.873.. Accuracy: 0.535
# Epoch 1/5.. Train loss: 2.557.. Validation loss: 1.870.. Accuracy: 0.528
# Epoch 1/5.. Train loss: 2.447.. Validation loss: 1.736.. Accuracy: 0.542
# Epoch 1/5.. Train loss: 2.328.. Validation loss: 1.439.. Accuracy: 0.641
# Epoch 1/5.. Train loss: 2.221.. Validation loss: 1.374.. Accuracy: 0.646
# Epoch 1/5.. Train loss: 2.237.. Validation loss: 1.367.. Accuracy: 0.661
# Epoch 1/5.. Train loss: 2.172.. Validation loss: 1.258.. Accuracy: 0.691
# Epoch 1/5.. Train loss: 2.095.. Validation loss: 1.219.. Accuracy: 0.700
# Epoch 1/5.. Train loss: 2.100.. Validation loss: 1.177.. Accuracy: 0.684
# Epoch 1/5.. Train loss: 1.819.. Validation loss: 1.183.. Accuracy: 0.693
# Epoch 1/5.. Train loss: 1.939.. Validation loss: 1.072.. Accuracy: 0.722
# Epoch 1/5.. Train loss: 1.892.. Validation loss: 1.057.. Accuracy: 0.727
# Epoch 1/5.. Train loss: 1.788.. Validation loss: 0.988.. Accuracy: 0.739
# Epoch 1/5.. Train loss: 1.578.. Validation loss: 1.004.. Accuracy: 0.741
# Epoch 1/5.. Train loss: 1.980.. Validation loss: 0.993.. Accuracy: 0.724
# Epoch 1/5.. Train loss: 1.573.. Validation loss: 0.980.. Accuracy: 0.716
# Epoch 1/5.. Train loss: 1.604.. Validation loss: 0.953.. Accuracy: 0.730
# Epoch 1/5.. Train loss: 1.914.. Validation loss: 0.906.. Accuracy: 0.764
# Epoch 1/5.. Train loss: 1.580.. Validation loss: 0.907.. Accuracy: 0.748
# Epoch 1/5.. Train loss: 1.696.. Validation loss: 0.805.. Accuracy: 0.786
# Epoch 1/5.. Train loss: 1.607.. Validation loss: 0.836.. Accuracy: 0.773
# Epoch 1/5.. Train loss: 1.485.. Validation loss: 0.831.. Accuracy: 0.786
# Epoch 1/5.. Train loss: 1.702.. Validation loss: 0.809.. Accuracy: 0.797
# Epoch 1/5.. Train loss: 1.427.. Validation loss: 0.859.. Accuracy: 0.769
# Epoch 1/5.. Train loss: 1.581.. Validation loss: 0.822.. Accuracy: 0.784
# Epoch 1/5.. Train loss: 1.533.. Validation loss: 0.781.. Accuracy: 0.791
# Epoch 1/5.. Train loss: 1.248.. Validation loss: 0.794.. Accuracy: 0.792
# Epoch 1/5.. Train loss: 1.153.. Validation loss: 0.776.. Accuracy: 0.782
# Epoch 1/5.. Train loss: 1.572.. Validation loss: 0.754.. Accuracy: 0.780
# Epoch 1/5.. Train loss: 1.494.. Validation loss: 0.761.. Accuracy: 0.799
# Time per epoch: 671.5142562389374 seconds
# Epoch 2/5.. Train loss: 1.264.. Validation loss: 0.733.. Accuracy: 0.802
# Epoch 2/5.. Train loss: 1.121.. Validation loss: 0.753.. Accuracy: 0.801
# Epoch 2/5.. Train loss: 1.170.. Validation loss: 0.787.. Accuracy: 0.796
# Epoch 2/5.. Train loss: 1.128.. Validation loss: 0.756.. Accuracy: 0.801
# Epoch 2/5.. Train loss: 1.355.. Validation loss: 0.743.. Accuracy: 0.815
# Epoch 2/5.. Train loss: 1.163.. Validation loss: 0.772.. Accuracy: 0.795
# Epoch 2/5.. Train loss: 0.999.. Validation loss: 0.731.. Accuracy: 0.784
# Epoch 2/5.. Train loss: 1.249.. Validation loss: 0.656.. Accuracy: 0.811
# Epoch 2/5.. Train loss: 1.012.. Validation loss: 0.671.. Accuracy: 0.814
# Epoch 2/5.. Train loss: 1.221.. Validation loss: 0.690.. Accuracy: 0.811
# Epoch 2/5.. Train loss: 1.074.. Validation loss: 0.686.. Accuracy: 0.809
# Epoch 2/5.. Train loss: 1.514.. Validation loss: 0.668.. Accuracy: 0.822
# Epoch 2/5.. Train loss: 1.347.. Validation loss: 0.658.. Accuracy: 0.822
# Epoch 2/5.. Train loss: 1.224.. Validation loss: 0.685.. Accuracy: 0.808
# Epoch 2/5.. Train loss: 1.159.. Validation loss: 0.632.. Accuracy: 0.826
# Epoch 2/5.. Train loss: 1.221.. Validation loss: 0.645.. Accuracy: 0.819
# Epoch 2/5.. Train loss: 1.185.. Validation loss: 0.624.. Accuracy: 0.831
# Epoch 2/5.. Train loss: 1.208.. Validation loss: 0.648.. Accuracy: 0.827
# Epoch 2/5.. Train loss: 1.366.. Validation loss: 0.625.. Accuracy: 0.836
# Epoch 2/5.. Train loss: 0.989.. Validation loss: 0.587.. Accuracy: 0.834
# Epoch 2/5.. Train loss: 1.396.. Validation loss: 0.596.. Accuracy: 0.843
# Epoch 2/5.. Train loss: 1.243.. Validation loss: 0.604.. Accuracy: 0.827
# Epoch 2/5.. Train loss: 1.321.. Validation loss: 0.619.. Accuracy: 0.835
# Epoch 2/5.. Train loss: 0.958.. Validation loss: 0.655.. Accuracy: 0.826
# Epoch 2/5.. Train loss: 1.085.. Validation loss: 0.629.. Accuracy: 0.827
# Epoch 2/5.. Train loss: 1.074.. Validation loss: 0.591.. Accuracy: 0.831
# Epoch 2/5.. Train loss: 1.131.. Validation loss: 0.588.. Accuracy: 0.838
# Epoch 2/5.. Train loss: 1.323.. Validation loss: 0.573.. Accuracy: 0.843
# Epoch 2/5.. Train loss: 1.107.. Validation loss: 0.596.. Accuracy: 0.836
# Epoch 2/5.. Train loss: 1.308.. Validation loss: 0.603.. Accuracy: 0.837
# Epoch 2/5.. Train loss: 1.172.. Validation loss: 0.575.. Accuracy: 0.843
# Epoch 2/5.. Train loss: 1.307.. Validation loss: 0.539.. Accuracy: 0.850
# Epoch 2/5.. Train loss: 0.955.. Validation loss: 0.566.. Accuracy: 0.837
# Epoch 2/5.. Train loss: 1.065.. Validation loss: 0.575.. Accuracy: 0.833
# Epoch 2/5.. Train loss: 1.100.. Validation loss: 0.554.. Accuracy: 0.844
# Epoch 2/5.. Train loss: 1.128.. Validation loss: 0.551.. Accuracy: 0.846
# Epoch 2/5.. Train loss: 1.203.. Validation loss: 0.541.. Accuracy: 0.840
# Epoch 2/5.. Train loss: 1.060.. Validation loss: 0.560.. Accuracy: 0.842
# Epoch 2/5.. Train loss: 1.140.. Validation loss: 0.618.. Accuracy: 0.824
# Epoch 2/5.. Train loss: 1.150.. Validation loss: 0.619.. Accuracy: 0.820
# Epoch 2/5.. Train loss: 1.087.. Validation loss: 0.578.. Accuracy: 0.849
# Time per epoch: 650.5680546760559 seconds
# Epoch 3/5.. Train loss: 0.879.. Validation loss: 0.608.. Accuracy: 0.829
# Epoch 3/5.. Train loss: 0.962.. Validation loss: 0.613.. Accuracy: 0.831
# Epoch 3/5.. Train loss: 0.928.. Validation loss: 0.567.. Accuracy: 0.843
# Epoch 3/5.. Train loss: 1.219.. Validation loss: 0.556.. Accuracy: 0.852
# Epoch 3/5.. Train loss: 1.058.. Validation loss: 0.563.. Accuracy: 0.851
# Epoch 3/5.. Train loss: 0.971.. Validation loss: 0.542.. Accuracy: 0.850
# Epoch 3/5.. Train loss: 0.997.. Validation loss: 0.549.. Accuracy: 0.846
# Epoch 3/5.. Train loss: 0.889.. Validation loss: 0.595.. Accuracy: 0.842
# Epoch 3/5.. Train loss: 1.086.. Validation loss: 0.577.. Accuracy: 0.837
# Epoch 3/5.. Train loss: 1.097.. Validation loss: 0.576.. Accuracy: 0.839
# Epoch 3/5.. Train loss: 1.047.. Validation loss: 0.583.. Accuracy: 0.835
# Epoch 3/5.. Train loss: 1.080.. Validation loss: 0.585.. Accuracy: 0.838
# Epoch 3/5.. Train loss: 1.078.. Validation loss: 0.523.. Accuracy: 0.858
# Epoch 3/5.. Train loss: 0.880.. Validation loss: 0.518.. Accuracy: 0.854
# Epoch 3/5.. Train loss: 1.000.. Validation loss: 0.538.. Accuracy: 0.858
# Epoch 3/5.. Train loss: 1.131.. Validation loss: 0.553.. Accuracy: 0.858
# Epoch 3/5.. Train loss: 0.923.. Validation loss: 0.533.. Accuracy: 0.852
# Epoch 3/5.. Train loss: 1.098.. Validation loss: 0.531.. Accuracy: 0.856
# Epoch 3/5.. Train loss: 0.853.. Validation loss: 0.522.. Accuracy: 0.855
# Epoch 3/5.. Train loss: 1.172.. Validation loss: 0.518.. Accuracy: 0.850
# Epoch 3/5.. Train loss: 0.880.. Validation loss: 0.584.. Accuracy: 0.838
# Epoch 3/5.. Train loss: 0.964.. Validation loss: 0.541.. Accuracy: 0.835
# Epoch 3/5.. Train loss: 0.893.. Validation loss: 0.507.. Accuracy: 0.867
# Epoch 3/5.. Train loss: 0.990.. Validation loss: 0.478.. Accuracy: 0.861
# Epoch 3/5.. Train loss: 0.937.. Validation loss: 0.480.. Accuracy: 0.862
# Epoch 3/5.. Train loss: 1.000.. Validation loss: 0.492.. Accuracy: 0.861
# Epoch 3/5.. Train loss: 0.891.. Validation loss: 0.535.. Accuracy: 0.850
# Epoch 3/5.. Train loss: 0.897.. Validation loss: 0.581.. Accuracy: 0.854
# Epoch 3/5.. Train loss: 0.907.. Validation loss: 0.555.. Accuracy: 0.846
# Epoch 3/5.. Train loss: 0.979.. Validation loss: 0.544.. Accuracy: 0.838
# Epoch 3/5.. Train loss: 0.950.. Validation loss: 0.521.. Accuracy: 0.854
# Epoch 3/5.. Train loss: 1.055.. Validation loss: 0.520.. Accuracy: 0.862
# Epoch 3/5.. Train loss: 1.028.. Validation loss: 0.503.. Accuracy: 0.860
# Epoch 3/5.. Train loss: 0.968.. Validation loss: 0.498.. Accuracy: 0.861
# Epoch 3/5.. Train loss: 0.803.. Validation loss: 0.501.. Accuracy: 0.859
# Epoch 3/5.. Train loss: 0.789.. Validation loss: 0.467.. Accuracy: 0.872
# Epoch 3/5.. Train loss: 1.004.. Validation loss: 0.473.. Accuracy: 0.878
# Epoch 3/5.. Train loss: 1.051.. Validation loss: 0.515.. Accuracy: 0.866
# Epoch 3/5.. Train loss: 0.878.. Validation loss: 0.571.. Accuracy: 0.840
# Epoch 3/5.. Train loss: 1.078.. Validation loss: 0.538.. Accuracy: 0.857
# Epoch 3/5.. Train loss: 1.018.. Validation loss: 0.500.. Accuracy: 0.858
# Time per epoch: 650.2463719844818 seconds
# Epoch 4/5.. Train loss: 0.769.. Validation loss: 0.508.. Accuracy: 0.864
# Epoch 4/5.. Train loss: 0.845.. Validation loss: 0.523.. Accuracy: 0.859
# Epoch 4/5.. Train loss: 0.869.. Validation loss: 0.548.. Accuracy: 0.851
# Epoch 4/5.. Train loss: 0.743.. Validation loss: 0.562.. Accuracy: 0.857
# Epoch 4/5.. Train loss: 0.821.. Validation loss: 0.544.. Accuracy: 0.856
# Epoch 4/5.. Train loss: 0.955.. Validation loss: 0.495.. Accuracy: 0.873
# Epoch 4/5.. Train loss: 1.069.. Validation loss: 0.466.. Accuracy: 0.872
# Epoch 4/5.. Train loss: 0.723.. Validation loss: 0.532.. Accuracy: 0.851
# Epoch 4/5.. Train loss: 0.818.. Validation loss: 0.605.. Accuracy: 0.842
# Epoch 4/5.. Train loss: 0.753.. Validation loss: 0.552.. Accuracy: 0.847
# Epoch 4/5.. Train loss: 0.851.. Validation loss: 0.511.. Accuracy: 0.864
# Epoch 4/5.. Train loss: 1.018.. Validation loss: 0.468.. Accuracy: 0.861
# Epoch 4/5.. Train loss: 0.908.. Validation loss: 0.462.. Accuracy: 0.876
# Epoch 4/5.. Train loss: 1.054.. Validation loss: 0.482.. Accuracy: 0.865
# Epoch 4/5.. Train loss: 0.836.. Validation loss: 0.504.. Accuracy: 0.861
# Epoch 4/5.. Train loss: 0.908.. Validation loss: 0.462.. Accuracy: 0.875
# Epoch 4/5.. Train loss: 0.894.. Validation loss: 0.481.. Accuracy: 0.863
# Epoch 4/5.. Train loss: 0.755.. Validation loss: 0.500.. Accuracy: 0.862
# Epoch 4/5.. Train loss: 0.991.. Validation loss: 0.510.. Accuracy: 0.858
# Epoch 4/5.. Train loss: 1.021.. Validation loss: 0.527.. Accuracy: 0.856
# Epoch 4/5.. Train loss: 0.703.. Validation loss: 0.501.. Accuracy: 0.863
# Epoch 4/5.. Train loss: 0.936.. Validation loss: 0.470.. Accuracy: 0.869
# Epoch 4/5.. Train loss: 0.732.. Validation loss: 0.435.. Accuracy: 0.886
# Epoch 4/5.. Train loss: 0.849.. Validation loss: 0.432.. Accuracy: 0.884
# Epoch 4/5.. Train loss: 0.834.. Validation loss: 0.450.. Accuracy: 0.888
# Epoch 4/5.. Train loss: 0.670.. Validation loss: 0.472.. Accuracy: 0.880
# Epoch 4/5.. Train loss: 0.981.. Validation loss: 0.459.. Accuracy: 0.881
# Epoch 4/5.. Train loss: 0.884.. Validation loss: 0.438.. Accuracy: 0.883
# Epoch 4/5.. Train loss: 0.672.. Validation loss: 0.469.. Accuracy: 0.868
# Epoch 4/5.. Train loss: 0.762.. Validation loss: 0.496.. Accuracy: 0.854
# Epoch 4/5.. Train loss: 0.925.. Validation loss: 0.529.. Accuracy: 0.853
# Epoch 4/5.. Train loss: 0.820.. Validation loss: 0.569.. Accuracy: 0.850
# Epoch 4/5.. Train loss: 1.004.. Validation loss: 0.531.. Accuracy: 0.853
# Epoch 4/5.. Train loss: 0.779.. Validation loss: 0.506.. Accuracy: 0.865
# Epoch 4/5.. Train loss: 0.756.. Validation loss: 0.500.. Accuracy: 0.868
# Epoch 4/5.. Train loss: 0.758.. Validation loss: 0.507.. Accuracy: 0.867
# Epoch 4/5.. Train loss: 0.838.. Validation loss: 0.496.. Accuracy: 0.872
# Epoch 4/5.. Train loss: 0.840.. Validation loss: 0.484.. Accuracy: 0.862
# Epoch 4/5.. Train loss: 0.963.. Validation loss: 0.518.. Accuracy: 0.845
# Epoch 4/5.. Train loss: 0.871.. Validation loss: 0.530.. Accuracy: 0.854
# Epoch 4/5.. Train loss: 0.824.. Validation loss: 0.516.. Accuracy: 0.874
# Time per epoch: 652.3080010414124 seconds
# Epoch 5/5.. Train loss: 0.813.. Validation loss: 0.526.. Accuracy: 0.864
# Epoch 5/5.. Train loss: 0.769.. Validation loss: 0.574.. Accuracy: 0.845
# Epoch 5/5.. Train loss: 0.812.. Validation loss: 0.536.. Accuracy: 0.844
# Epoch 5/5.. Train loss: 1.016.. Validation loss: 0.510.. Accuracy: 0.859
# Epoch 5/5.. Train loss: 0.710.. Validation loss: 0.506.. Accuracy: 0.863
# Epoch 5/5.. Train loss: 0.846.. Validation loss: 0.465.. Accuracy: 0.866
# Epoch 5/5.. Train loss: 0.853.. Validation loss: 0.450.. Accuracy: 0.873
# Epoch 5/5.. Train loss: 0.758.. Validation loss: 0.469.. Accuracy: 0.864
# Epoch 5/5.. Train loss: 0.811.. Validation loss: 0.451.. Accuracy: 0.874
# Epoch 5/5.. Train loss: 0.702.. Validation loss: 0.440.. Accuracy: 0.873
# Epoch 5/5.. Train loss: 0.860.. Validation loss: 0.438.. Accuracy: 0.868
# Epoch 5/5.. Train loss: 0.938.. Validation loss: 0.438.. Accuracy: 0.886
# Epoch 5/5.. Train loss: 1.046.. Validation loss: 0.464.. Accuracy: 0.873
# Epoch 5/5.. Train loss: 0.896.. Validation loss: 0.455.. Accuracy: 0.877
# Epoch 5/5.. Train loss: 0.863.. Validation loss: 0.423.. Accuracy: 0.877
# Epoch 5/5.. Train loss: 0.774.. Validation loss: 0.423.. Accuracy: 0.875
# Epoch 5/5.. Train loss: 0.876.. Validation loss: 0.432.. Accuracy: 0.872
# Epoch 5/5.. Train loss: 0.865.. Validation loss: 0.411.. Accuracy: 0.872
# Epoch 5/5.. Train loss: 0.718.. Validation loss: 0.429.. Accuracy: 0.872
# Epoch 5/5.. Train loss: 0.821.. Validation loss: 0.451.. Accuracy: 0.868
# Epoch 5/5.. Train loss: 0.822.. Validation loss: 0.485.. Accuracy: 0.860
# Epoch 5/5.. Train loss: 0.887.. Validation loss: 0.479.. Accuracy: 0.872
# Epoch 5/5.. Train loss: 0.771.. Validation loss: 0.455.. Accuracy: 0.876
# Epoch 5/5.. Train loss: 0.831.. Validation loss: 0.440.. Accuracy: 0.875
# Epoch 5/5.. Train loss: 0.843.. Validation loss: 0.478.. Accuracy: 0.870
# Epoch 5/5.. Train loss: 0.753.. Validation loss: 0.466.. Accuracy: 0.886
# Epoch 5/5.. Train loss: 0.863.. Validation loss: 0.447.. Accuracy: 0.882
# Epoch 5/5.. Train loss: 0.776.. Validation loss: 0.500.. Accuracy: 0.870
# Epoch 5/5.. Train loss: 0.950.. Validation loss: 0.539.. Accuracy: 0.859
# Epoch 5/5.. Train loss: 0.902.. Validation loss: 0.533.. Accuracy: 0.862
# Epoch 5/5.. Train loss: 0.663.. Validation loss: 0.455.. Accuracy: 0.880
# Epoch 5/5.. Train loss: 0.938.. Validation loss: 0.424.. Accuracy: 0.895
# Epoch 5/5.. Train loss: 0.802.. Validation loss: 0.403.. Accuracy: 0.895
# Epoch 5/5.. Train loss: 0.756.. Validation loss: 0.403.. Accuracy: 0.887
# Epoch 5/5.. Train loss: 0.666.. Validation loss: 0.391.. Accuracy: 0.892
# Epoch 5/5.. Train loss: 0.742.. Validation loss: 0.389.. Accuracy: 0.894
# Epoch 5/5.. Train loss: 0.585.. Validation loss: 0.411.. Accuracy: 0.897
# Epoch 5/5.. Train loss: 0.765.. Validation loss: 0.435.. Accuracy: 0.895
# Epoch 5/5.. Train loss: 0.651.. Validation loss: 0.448.. Accuracy: 0.886
# Epoch 5/5.. Train loss: 0.784.. Validation loss: 0.452.. Accuracy: 0.884
# Epoch 5/5.. Train loss: 0.908.. Validation loss: 0.407.. Accuracy: 0.888
# Time per epoch: 650.8412160873413 seconds

# %%
# Visualize training process to observe possible overfitting
plt.plot(losses_train, label='Training loss')
plt.plot(losses_validation, label='Validation loss')
plt.legend(frameon=False)

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
accuracy_test = 0
loss_test = 0
losses_test = []

with torch.no_grad():
    model.to(device)
    for inputs, labels in test_dataloaders:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model.forward(inputs)
        loss_test += criterion(outputs, labels).item()
                            
        # Calculate probability
        ps = torch.exp(outputs)
        top_p, top_class = ps.topk(1, dim=1)
        
        # Calculate accuracy
        equality = top_class == labels.view(*top_class.shape)
        accuracy_test += torch.mean(equality.type(torch.FloatTensor)).item()
        losses_test.append(loss_test/len(test_dataloaders))

print('Accuracy of the network on the test images: %d %%' % (100 * accuracy_test/len(test_dataloaders)))
# Out:
# Accuracy of the network on the test images: 84 %

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint
checkpoint = {'model_state_dict': model.state_dict(),
              'model_classifier': model.classifier,
              'class_to_idx': train_image_datasets.class_to_idx,
              'optimizier_state_dict': optimizer.state_dict(),
              'epochs': epochs}

torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    
    model.load_state_dict = checkpoint['model_state_dict']
    model.classifier = checkpoint['model_classifier'] 
    model.class_to_idx = checkpoint['class_to_idx']
    
    optimizer.load_state_dict(checkpoint['optimizier_state_dict'])
    epoch = checkpoint['epochs']
    
    return model, optimizer, epoch

# %%
# Check the function "load_checkpoint"
model_inference, _, _ = load_checkpoint('checkpoint.pth')
model_inference
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=512, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2)
#     (fc2): Linear(in_features=512, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    img_pil = Image.open(image)
    
    transform = transforms.Compose([transforms.Resize(255),
                                    transforms.CenterCrop(224),
                                    transforms.ToTensor(),
                                    transforms.Normalize([0.485, 0.456, 0.406],
                                                         [0.229, 0.224, 0.225])])
    
    pil_transformed = transform(img_pil)
    np_array_img = np.array(pil_transformed)
    
    return np_array_img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
        
    ax.imshow(image)
    
    return ax

# %%
image_path = 'flowers/train/10/image_07086.jpg'
img = process_image(image_path)
imshow(img)

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, device, topk=5):
    model = model.to(device)
    
    # Pre-processed image
    image = process_image(image_path)
    
    if device.type == 'cuda':
        img = torch.from_numpy(image).type(torch.cuda.FloatTensor)
    else:
        img = torch.from_numpy(image).type(torch.FloatTensor)
    
    img_unsqueezed = img.unsqueeze_(0)
    
    model.eval()
    with torch.no_grad():
        output = model.forward(img_unsqueezed.to(device))
    
    # Calculate probabilities
    ps = torch.exp(output)
    ps_topk, indices = ps.topk(topk)
    
    # Convert to cpu() due to the computational problem
    ps_topk = ps_topk.cpu()
    indices = indices.cpu()
    
    ps_numpy = ps_topk.numpy()[0]
    # Converting probability to list
    ps_list = np.array(ps_topk)[0]
    indices = np.array(indices)[0]
    
    # Load class
    idx_class = model.class_to_idx
    index_class = {val: key for key, val in idx_class.items()}
    classes = [index_class[i] for i in indices]
    
    return ps_numpy, classes

# %%
# Test function "predict"
test_image = test_dir + '/10/image_07104.jpg'
probs, classes = predict(test_image, model_inference, device, topk=5)

print("Probabilities = ", probs)
print("Classes = ", classes)
# Out:
# Probabilities =  [  1.00000000e+00   9.84785871e-08   6.59434229e-10   5.37269895e-10
#    9.48387809e-12]
# Classes =  ['10', '14', '35', '92', '29']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
def sanity_check(image_path, model):
        
    prob, classes = predict(image_path, model, device)
    image = process_image(image_path)
    index = image_path.split(sep='/')[2]
    
    ax = imshow(image)
    ax.set_title(cat_to_name[str(index)])
    
    class_names = [cat_to_name[i] for i in classes]
    
    plt.figure(figsize=(5,10))
    plt.subplot(2,1,2)
    
    sns.barplot(x=prob, y=class_names)
    plt.show()

# %%
sanity_check(test_image, model_inference)

# %%
test_image = test_dir + '/5/image_05186.jpg'
sanity_check(test_image, model_inference)

# %%
test_image = test_dir + '/5/image_05159.jpg'
sanity_check(test_image, model_inference)
